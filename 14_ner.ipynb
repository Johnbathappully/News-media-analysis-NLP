# %% [markdown]
# # Named Entity Recognition on news articles

# %% [markdown]
# ### I downloaded the dataset from https://www.kaggle.com/snapcrack/all-the-news
# The first file contains 50000 articles

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" #default 'last_expr'

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re
# Datasets from https://www.kaggle.com/snapcrack/all-the-news
#import os
#print(os.listdir("all-the-news/"))
# Read one csv
df = pd.read_csv("all-the-news/articles1.csv")
df.head()
# Out:
#    Unnamed: 0     id                                              title  \
# 0           0  17283  House Republicans Fret About Winning Their Hea...
# 1           1  17284  Rift Between Officers and Residents as Killing...
# 2           2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3           3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4           4  17287  Kim Jong-un Says North Korea Is Preparing to T...
#
#       publication                         author        date    year  month  \
# 0  New York Times                     Carl Hulse  2016-12-31  2016.0   12.0
# 1  New York Times  Benjamin Mueller and Al Baker  2017-06-19  2017.0    6.0
# 2  New York Times                   Margalit Fox  2017-01-06  2017.0    1.0
# 3  New York Times               William McDonald  2017-04-10  2017.0    4.0
# 4  New York Times                  Choe Sang-Hun  2017-01-02  2017.0    1.0
#
#    url                                            content
# 0  NaN  WASHINGTON  —   Congressional Republicans have...
# 1  NaN  After the bullet shells get counted, the blood...
# 2  NaN  When Walt Disney’s “Bambi” opened in 1942, cri...
# 3  NaN  Death may be the great equalizer, but it isn’t...
# 4  NaN  SEOUL, South Korea  —   North Korea’s leader, ...

# %% [markdown]
# #### Import spacy and define a dictionary to convert entity type to a more human-readable description

# %%
import spacy
from spacy import displacy
nlp = spacy.load('en')
dict_entity_type = {'PERSON':'Person',
'NORP':'Group',
'FAC':'Building',
'ORG':'Organization',
'GPE':'Place',
'LOC':'Location',
'PRODUCT':'Product',
'EVENT':'Event',
'WORK_OF_ART':'Title',
'LAW':'Legal',
'LANGUAGE':'Language',
'DATE':'Date',
'TIME':'Time',
'PERCENT':'Percentage',
'MONEY':'Value',
'QUANTITY':'Quantity',
'ORDINAL':'Ordinal',
'CARDINAL':'Number'}

# %% [markdown]
# ## Define the corpus. If you have a fast computer increase the number of articles

# %%
corpus = df.iloc[0:2000].content.apply(lambda x: re.sub(' +', ' ',x))

# %% [markdown]
# #### Build a data frame of all the named entities and their types

# %%
named_entities = []
for i,article in enumerate(corpus):
    article = nlp(article)
    for element in article.ents:
        named_entities.append((element.text, element.label_, i))

entity_frame = pd.DataFrame(named_entities, columns=['Name', 'Type', 'Document number'])

# %% [markdown]
# #### Get the top named entity types

# %%
top_entities = (entity_frame.groupby(by=['Type'])
                           .size()
                           .sort_values(ascending=False)
                           .reset_index().rename(columns={0 : 'Frequency'}))
top_entities.T.iloc[:,:15]
# Out:
#                0      1      2      3         4      5        6     7     8   \
# Type       PERSON    ORG    GPE   DATE  CARDINAL   NORP  ORDINAL  TIME   LOC
# Frequency   58912  32462  31304  30182     17812  16399     3491  3222  3147
#
#                     9      10    11       12     13        14
# Type       WORK_OF_ART  MONEY   FAC  PERCENT  EVENT  QUANTITY
# Frequency         3000   2654  1932     1551   1145       987

# %% [markdown]
# #### Get the top named entities

# %%
top_entities = (entity_frame.groupby(by=['Name', 'Type'])
                           .size()
                           .sort_values(ascending=False)
                           .reset_index().rename(columns={0 : 'Frequency'}))
top_entities.T.iloc[:,:15]
# Out:
#                0         1        2                  3         4         5   \
# Name        Trump       one    first  the United States  American       two
# Type       PERSON  CARDINAL  ORDINAL                GPE      NORP  CARDINAL
# Frequency    7116      2507     2310               2066      1912      1831
#
#                6           7       8      9         10           11  \
# Name        Obama  Republican  Russia  China       000  Republicans
# Type       PERSON        NORP     GPE    GPE  CARDINAL         NORP
# Frequency    1368        1115    1062   1020       977          975
#
#                    12       13         14
# Name       Washington  Russian  Democrats
# Type              GPE     NORP       NORP
# Frequency         864      784        748

# %% [markdown]
# ## Example: categorize the first article
# Compute the named entities, then print the most important keywords

# %%
article = corpus.iloc[0]
article = nlp(article)
df = [(element.text, element.label_) for element in article.ents]
df = pd.DataFrame(df, columns=['Name', 'Type'])

top = (df.groupby(by=['Name', 'Type'])
                           .size()
                           .sort_values(ascending=False)
                           .reset_index().rename(columns={0 : 'Frequency'}))
# Show the top named entities
#top.T.iloc[:,:15]

# Get the top named entities, print a maximum of 6
quant09 = np.quantile(top.Frequency,0.9)
top_ent = top[top['Frequency']>=quant09][0:6]
gr = top_ent.groupby(by='Type')
from IPython.display import HTML
HTML("<b>Keywords:</b>")
for k in gr.groups.keys():
    keywords =+ top_ent[top_ent['Type']==k].Name
    print(dict_entity_type[k]+': ',', '.join(keywords))
# Out:
# <b>Keywords:</b>
# Group:  Republicans, Trump
# Organization:  House, Congress
# Person:  Obama

# %% [markdown]
# #### Display named entities in some sentence of the the first article

# %%
sentences = [x for x in article.sents]
n = 12 #12th sentence

for element in nlp(str(sentences[n])).ents:
    print('%s, Type: %s' % (element, element.label_))
    
displacy.render(nlp(str(sentences[n])), style='ent', jupyter=True)
displacy.render(nlp(str(sentences[n])), style='dep', jupyter=True, options={'distance': 100})
# Out:
# 2015, Type: DATE
# Rosemary M. Collyer, Type: PERSON
# House, Type: ORG
# Republicans, Type: NORP
# Obama, Type: PERSON
# Constitution, Type: LAW
# Congress, Type: ORG
# <div class="entities" style="line-height: 2.5">In a potentially decision in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , Judge
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Rosemary M. Collyer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ruled that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Republicans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  had the standing to sue the executive branch over a spending dispute and that the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  administration had been distributing the health insurance subsidies, in violation of the
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Constitution
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# , without approval from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Congress
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="234-0" class="displacy" width="4750" height="587.0" style="max-width: none; height: 587.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">potentially</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">decision</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">2015,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Judge</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Rosemary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">M.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Collyer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">ruled</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">House</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">Republicans</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">had</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">standing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">sue</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">executive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">branch</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2350">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">spending</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2550">dispute</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2950">Obama</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">administration</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="m

# %% [markdown]
# ## What to do next
# * Explore summarization of content
# * It would be fun to create a recommendation system using named entities
